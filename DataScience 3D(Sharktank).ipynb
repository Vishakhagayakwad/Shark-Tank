# %% [markdown]
# # 1.	Complete basic EDA part, check for head, tail, info, null values, duplicate values.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv(r'C:\Users\Welcome\Desktop\Data Science Internship\CSV FILES\Shark_Tank_India.csv')
df
# Out:
#      Episode Number  Pitch Number                Brand  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               Idea  \
# 0                                     Frozen Momos
# 1    Renting e-bike for mobility in private spaces
# 2                               Detachable Sleeves
# 3                             Healthy Potato Chips
# ...

# %%
df.head()
# Out:
#    Episode Number  Pitch Number                Brand  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             Idea  \
# 0                                   Frozen Momos
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
# 3                           Healthy Potato Chips
# 4                       Brain Development Course
#
#    Investment Amount (In Lakhs INR)   Debt (In lakhs INR)  Equity   \
# 0                                 75                    0     0.18
# 1                                 40                    0     0.50
# 2                                 25                    0     0.30
# 3                                 70                    0     0.03
# ...

# %%
df.tail()
# Out:
#      Episode Number  Pitch Number          Brand                    Idea  \
# 112              34           113  Green Protein     Plant-Based Protein
# 113              34           114        On2Cook  Fastest Cooking Device
# 114              35           115  Jain Shikanji                Lemonade
# 115              35           116          Woloo         Washroom Finder
# 116              35           117   Elcare India    Carenting for Elders
#
#      Investment Amount (In Lakhs INR)   Debt (In lakhs INR)  Equity   \
# 112                                  0                    0      0.0
# 113                                  0                    0      0.0
# 114                                 40                    0      0.3
# 115                                  0                    0      0.0
# 116                                  0                    0      0.0
#
#      Valuation Offered (In Lakhs INR) Anupam Ashneer Namita Aman Peyush  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Episode Number                     117 non-null    int64
#  1   Pitch Number                       117 non-null    int64
#  2   Brand                              117 non-null    object
#  3   Idea                               117 non-null    object
#  4   Investment Amount (In Lakhs INR)   117 non-null    int64
#  5   Debt (In lakhs INR)                117 non-null    int64
#  6   Equity                             117 non-null    float64
#  7   Valuation Offered (In Lakhs INR)   117 non-null    float64
#  8   Anupam                             117 non-null    object
#  9   Ashneer                            117 non-null    object
#  10  Namita                             117 non-null    object
# ...

# %% [markdown]
# # 2.	Clean the data set if there is any null values or duplicate values.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Episode Number                       0
# Pitch Number                         0
# Brand                                0
# Idea                                 0
# Investment Amount (In Lakhs INR)     0
# Debt (In lakhs INR)                  0
# Equity                               0
# Valuation Offered (In Lakhs INR)     0
# Anupam                               0
# Ashneer                              0
# Namita                               0
# Aman                                 0
# Peyush                               0
# Vineeta                              0
# Ghazal                               0
# dtype: int64

# %% [markdown]
# # 3.	Find how many start up received the funds

# %%
df_deals = df[df['Investment Amount (In Lakhs INR) ']>0]

# %%
df_deals.shape
# Out:
# (65, 15)

# %% [markdown]
# # 4.	How many Sharks were in for Each Brand?

# %%
df1 = df.copy()

# %%
df1 = df1.replace({'Out':0,'In':1})

# %%
df1['Sharks _In'] = df1['Anupam']+df1['Ashneer']+df1['Namita']+df1['Aman']+df1['Peyush']+df1['Vineeta']+df1['Ghazal']

# %%
df1.head()
# Out:
#    Episode Number  Pitch Number                Brand  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             Idea  \
# 0                                   Frozen Momos
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
# 3                           Healthy Potato Chips
# 4                       Brain Development Course
#
#    Investment Amount (In Lakhs INR)   Debt (In lakhs INR)  Equity   \
# 0                                 75                    0     0.18
# 1                                 40                    0     0.50
# 2                                 25                    0     0.30
# 3                                 70                    0     0.03
# ...

# %%
df1['Sharks _In'].max()
# Out:
# 5

# %% [markdown]
# # 4a. Check how many brands are there where 5 Sharks were IN

# %%
df[df1['Sharks _In']==5]
# Out:
#     Episode Number  Pitch Number                  Brand                 Idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     Investment Amount (In Lakhs INR)   Debt (In lakhs INR)  Equity   \
# 15                                 10                    0     0.15
# 49                                 50                    0     0.25
# 63                                 10                    0     0.10
# 79                                 10                    0     0.06
#
#     Valuation Offered (In Lakhs INR) Anupam Ashneer Namita Aman Peyush  \
# 15                             66.67     In      In     In   In    Out
# 49                            200.00     In      In     In   In     In
# ...

# %% [markdown]
# # 5.	Find Interest of Sharks

# %%
shark_in = [df1['Anupam'].sum(),df1['Ashneer'].sum(),df1['Namita'].sum(),df1['Aman'].sum(),df1['Peyush'].sum(),df1['Vineeta'].sum(),df1['Ghazal'].sum()]

# %%
sharks = ['Anupam','Ashneer','Namita','Aman','Peyush','Vineeta','Ghazal']

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=sharks, y=shark_in, palette='rainbow')
plt.xlabel('Sharks')
plt.ylabel('Number of Companies they were interested In')
plt.title("Interest of Sharks", fontsize = 15)
plt.plot()
# Out:
# []

# %% [markdown]
# # 6.	In which Episode Maximum Pitches were made?

# %%
df1.groupby(['Episode Number'])['Pitch Number'].count().sort_values(ascending = False).reset_index().head(11)
# Out:
#     Episode Number  Pitch Number
# 0               18             4
# 1               30             4
# 2               17             4
# 3               16             4
# 4               22             4
# 5               23             4
# 6               27             4
# 7               31             4
# 8               32             4
# 9               33             4
# 10              34             4

# %% [markdown]
# # 7.	Find Top 5 Investments

# %%
investment=df.groupby('Brand')['Investment Amount (In Lakhs INR) '].sum().sort_values(ascending = False).reset_index().head(5)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=investment['Brand'], y=investment['Investment Amount (In Lakhs INR) '],palette='rocket')
plt.xticks(rotation = 45)
plt.xlabel('Brands')
plt.ylabel('Investment Amount (In Lakhs INR)')
plt.title("Top 5 Investments", fontsize = 15)
plt.plot()
# Out:
# []

# %% [markdown]
# # 8.	Find Top 10 Valued Companies

# %%
top_valued=df.groupby('Brand')['Valuation Offered (In Lakhs INR)'].sum().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=top_valued['Brand'], y=top_valued['Valuation Offered (In Lakhs INR)'],palette='rocket')
plt.xticks(rotation = 45)
plt.xlabel('Brands')
plt.ylabel('Valuation Offered (In Lakhs INR)')
plt.title("Top 10 valued companies", fontsize = 15)
plt.plot()
# Out:
# []

# %% [markdown]
# # 9.	Find Brands Which Received Debt from Sharks

# %%
 df[[df.groupby('Brand')['Investment Amount (In Lakhs INR) ']]>0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df[[df.groupby('Brand')['Investment Amount (In Lakhs INR) ']]>0]
#
# TypeError: '>' not supported between instances of 'list' and 'int'
